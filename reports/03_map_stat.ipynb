# %%
# !pip install geopandas matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 KB 858.2 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 1.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 1.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.6/159.6 KB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/home/nick/transportation/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 29
#      25     return s
#      28 # Проход по структуре
# ---> 29 for highway_folder in os.listdir(OUTPUT_BASE):
#      30     folder_path = os.path.join(OUTPUT_BASE, highway_folder)
#      31     if not os.path.isdir(folder_path):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/'
